# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1 Adding a new column

# %% [markdown]
# ### 1.1 Adding a new column with a scalar value

# %%
# adding new colum to dataframe
df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %% [markdown]
# ### 1.2 Adding a new column with an array

# %% [raw]
# The dataframe has 100 rows, so we need to create an array with 1000 elements

# %%
# import numpy
import numpy as np

# %%
# create an array of 1000 elements
language_score = np.arange(0, 1000)

# %%
# length of the array
len(language_score)
# Out:
# 1000

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
# create random integer numbers between 1 and 100
int_language_score = np.random.randint(1, 100, size=1000)

# %%
# min value inclusive and high vlue exclusive
min(int_language_score)
max(int_language_score)
# Out:
# np.int32(99)

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                31
# 1                66
# 2                70
# 3                37
# 4                69
# ..              ...
# 995              65
# 996              23
# 997              86
# 998              17
# 999              17
#
# [1000 rows x 9 columns]

# %%
# create random float number between 1 and 100
np.random.uniform(1, 100, size=100)
# Out:
# array([ 2.31626898, 71.7184875 , 58.73082178, 73.49304893, 94.72260296,
#        35.83453281, 79.82116327, 10.05239559, 50.76777303, 79.47552142,
#        72.56394279, 35.94348588, 30.43380622, 32.60996591, 85.48987337,
#        37.22362047, 30.29859564, 21.77070346, 44.48815767, 10.0561282 ,
#        48.63232948,  8.08662161, 50.42960655, 38.27565645,  1.93928223,
#        39.26570411, 65.53422047, 36.32056739, 91.11887523, 90.92158684,
#        57.06323128, 57.1646548 , 49.84659796, 25.56564138, 71.05107028,
#        17.18871653,  9.94735065, 57.06896768, 12.66955413, 97.25001076,
#        24.1043509 , 14.09762655,  8.00272623, 83.53281019, 99.63173637,
#        87.95108305, 56.6223819 ,  9.74868779, 90.37910062, 52.47637102,
#        48.92790179, 80.17904841, 12.26918611, 88.26708271,  3.71418746,
#         4.25830275, 79.8714825 , 37.25096719, 51.17627135, 29.364924  ,
#        56.87592454, 38.65722127, 56.67094181, 80.54258971, 11.08270342,
#        16.26818368,  9.87250425, 82.73749773, 53.15075971, 65.68397793,
#        66.34674495, 60.3332281 , 32.29333838, 14.06629937, 78.5123768 ,
#        20.26221421, 42.95765453, 10.32250934, 48.27903468, 70.32930563,
#        87.04557977, 86.81674026, 23.99262485, 14.94316398, 50.03960768,
#        97.69991169, 15.88614726, 81.51531102, 28.84285078, 27.57948978,
#        92.90228191, 12.85535336, 90.63062652, 15.34797159, 67.44887595,
#        80.284969  , 32.48901405, 17.72899675, 90.17983715, 81.55481144])
